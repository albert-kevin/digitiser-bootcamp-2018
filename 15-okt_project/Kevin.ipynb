# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
! ls -al
# Out:
# total 1676
# drwxrwxr-x  3 ubuntu ubuntu    4096 Oct 15 08:33 .
# drwxrwxr-x 12 ubuntu ubuntu    4096 Oct 17 08:18 ..
# -rw-rw-r--  1 ubuntu ubuntu 1105249 Oct 12 19:18 Credit_DataSet.xlsx
# drwxrwxr-x  2 ubuntu ubuntu    4096 Oct 15 08:10 .ipynb_checkpoints
# -rw-rw-r--  1 ubuntu ubuntu   66564 Oct 15 08:17 Kevin.ipynb
# -rw-rw-r--  1 ubuntu ubuntu   33935 Oct 15 08:33 Untitled.ipynb
# -rw-rw-r--  1 ubuntu ubuntu  490374 Oct 15 08:17 Vuong.ipynb

# %%
########################################################################### 
# Exercises Part I --------------------------------------------------------
###########################################################################
total = pd.read_excel("Credit_DataSet.xlsx", sheet_name="DATA")

# %%
#show the variables vertically to see all the Variables
total.head(10).T
# Out:
#                                        0                               1  \
# ID                                     1                               2
# INDUSTRY_GROUP                 Materials  Semiconductors & Semiconductor
# INDUSTRY                       Chemicals  Semiconductors & Semiconductor
# SECTOR                         Materials          Information Technology
# CURRENCY                             EDM                             EDM
# DEFAULT_PROB                    0.611768                        0.728919
# NBR_EMPLOYEES                     113830                           36962
# EMPL_GROWTH                      1.24072                          1.8265
# PCT_WOMEN_EMPLOYEES                 24.6                            37.3
# PCT_WOMEN_MGT                       19.8                             NaN
# WHISTLE_BLOWER_POLICY                  Y                               Y
# ETHICS_POLICY                          Y                               Y
# ...

# %%
# several different functions exist to have a look at the structure of the raw data
#this shows the numerical data descriptive numbers
#include all and also percentiles
total.describe(include='all', percentiles=[.05, .25, .5, .75, 0.95]).T
# Out:
#                             count unique            top  freq         mean  \
# ID                           3933    NaN            NaN   NaN         1967
# INDUSTRY_GROUP               3933     24  Capital Goods   663          NaN
# INDUSTRY                     3933     66      Machinery   247          NaN
# SECTOR                       3933     11    Industrials   974          NaN
# CURRENCY                      398     17            GBP   105          NaN
# DEFAULT_PROB                 3933    NaN            NaN   NaN      1.63962
# NBR_EMPLOYEES                3933    NaN            NaN   NaN      13536.5
# EMPL_GROWTH                  3809    NaN            NaN   NaN      25.0823
# PCT_WOMEN_EMPLOYEES           630    NaN            NaN   NaN      33.1429
# PCT_WOMEN_MGT                 328    NaN            NaN   NaN       21.164
# WHISTLE_BLOWER_POLICY        1930      2              Y  1561          NaN
# ...

# %%
#show the sape of the dataset
total.shape
# Out:
# (3933, 32)

# %%
total.info(memory_usage='deep', verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933 entries, 0 to 3932
# Data columns (total 32 columns):
# ID                             3933 non-null int64
# INDUSTRY_GROUP                 3933 non-null object
# INDUSTRY                       3933 non-null object
# SECTOR                         3933 non-null object
# CURRENCY                       398 non-null object
# DEFAULT_PROB                   3933 non-null float64
# NBR_EMPLOYEES                  3933 non-null int64
# EMPL_GROWTH                    3809 non-null float64
# PCT_WOMEN_EMPLOYEES            630 non-null float64
# PCT_WOMEN_MGT                  328 non-null float64
# WHISTLE_BLOWER_POLICY          1930 non-null object
# ETHICS_POLICY                  1935 non-null object
# BRIBERY_POLICY                 1920 non-null object
# COUNTRY                        3933 non-null object
# COUNTRY_NAME                   3933 non-null object
# COUNTRY_RISK_GROWTH_RATE       3933 non-null float64
# ...

# %%
import pandas_profiling as pp

# %%
#display report
pp.ProfileReport(total)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...
