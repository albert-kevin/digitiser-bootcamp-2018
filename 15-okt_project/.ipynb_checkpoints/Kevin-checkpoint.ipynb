# %%
import pandas as pd

# %%
df = pd.read_excel("Credit_DataSet.xlsx", sheet_name="DATA")

# %%
df
# Out:
#         ID                  INDUSTRY_GROUP                        INDUSTRY  \
# 0        1                       Materials                       Chemicals
# 1        2  Semiconductors & Semiconductor  Semiconductors & Semiconductor
# 2        3        Food, Beverage & Tobacco                         Tobacco
# 3        4                       Retailing                Specialty Retail
# 4        5        Food, Beverage & Tobacco                   Food Products
# 5        6        Food, Beverage & Tobacco                   Food Products
# 6        7                   Capital Goods               Building Products
# 7        8             Software & Services                        Software
# 8        9        Food, Beverage & Tobacco                       Beverages
# 9       10     Consumer Durables & Apparel  Textiles, Apparel & Luxury Goo
# 10      11  Pharmaceuticals, Biotechnology                 Pharmaceuticals
# ...
