# %%
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
with open('2vr3-k9wn.json') as json_data: #we create an alias "json_data" and read the file content as read-only mode
    data = json.load(json_data)           #we translate this raw text data into json format and store it in "data"
    df = pd.DataFrame(data)             #we load this data into a DataFrame and overwrite the original called "data"
   #print(data.head(10))
   #print(data.columns)
# ! I had to correct indentation here
# let's rename the DataFrame into df for verification purposes

# %%
#let's check the content of the original file, the data and df

# %%
#original raw data
! tail -n 5 "2vr3-k9wn.json"
# Out:
# ,{"designation":"(2010 CO1)","discovery_date":"2010-02-01T00:00:00.000","h_mag":"21.5","i_deg":"24.03","moid_au":"0.023","orbit_class":"Apollo","period_yr":"1.02","pha":"Y","q_au_1":"0.79","q_au_2":"1.23"}
# ,{"designation":"P/2010 B2 (WISE)","discovery_date":"2010-01-22T00:00:00.000","i_deg":"8.93","moid_au":"0.63","orbit_class":"Encke-type Comet","period_yr":"5.49","pha":"n/a","q_au_1":"1.62","q_au_2":"4.6"}
# ,{"designation":"(2010 AU118)","discovery_date":"2010-01-13T00:00:00.000","h_mag":"17.7","i_deg":"43.73","moid_au":"0.147","orbit_class":"Amor","period_yr":"2.06","pha":"N","q_au_1":"1.13","q_au_2":"2.12"}
# ,{"designation":"(2010 AG79)","discovery_date":"2010-01-13T00:00:00.000","h_mag":"19.9","i_deg":"32.96","moid_au":"0.244","orbit_class":"Amor","period_yr":"4.95","pha":"N","q_au_1":"1.22","q_au_2":"4.59"}
# ...

# %%
#show the json structure 
data
# Out:
# [{'designation': '419880 (2011 AH37)',
#   'discovery_date': '2011-01-07T00:00:00.000',
#   'h_mag': '19.7',
#   'i_deg': '9.65',
#   'moid_au': '0.035',
#   'orbit_class': 'Apollo',
#   'period_yr': '4.06',
#   'pha': 'Y',
#   'q_au_1': '0.84',
#   'q_au_2': '4.26'},
#  {'designation': '419624 (2010 SO16)',
#   'discovery_date': '2010-09-17T00:00:00.000',
#   'h_mag': '20.5',
#   'i_deg': '14.52',
#   'moid_au': '0.028',
#   'orbit_class': 'Apollo',
#   'period_yr': '1',
#   'pha': 'Y',
#   'q_au_1': '0.93',
#   'q_au_2': '1.08'},
#  {'designation': '414772 (2010 OC103)',
#   'discovery_date': '2010-07-28T00:00:00.000',
#   'h_mag': '19',
#   'i_deg': '23.11',
#   'moid_au': '0.333',
#   'orbit_class': 'Apollo',
#   'period_yr': '1.31',
#   'pha': 'N',
#   'q_au_1': '0.39',
#   'q_au_2': '2'},
#  {'designation': '414746 (2010 EH20)',
#   'discovery_date': '2010-03-06T00:00:00.000',
#   'h_mag': '18',
#   'i_deg': '23.89',
#   'moid_au': '0.268',
#   'orbit_class': 'Amor',
# ...

# %%
#then how pandas read the dictionary structure
df.head(10)
#looks good to me
# Out:
#            designation           discovery_date h_mag  i_deg moid_au  \
# 0   419880 (2011 AH37)  2011-01-07T00:00:00.000  19.7   9.65   0.035
# 1   419624 (2010 SO16)  2010-09-17T00:00:00.000  20.5  14.52   0.028
# 2  414772 (2010 OC103)  2010-07-28T00:00:00.000    19  23.11   0.333
# 3   414746 (2010 EH20)  2010-03-06T00:00:00.000    18  23.89   0.268
# 4  407324 (2010 OB101)  2010-07-18T00:00:00.000  20.7   9.12   0.111
# 5   398188 (2010 LE15)  2010-06-03T00:00:00.000  19.5  13.25   0.024
# 6   395207 (2010 HQ80)  2010-04-25T00:00:00.000  19.6  27.85   0.007
# 7   386847 (2010 LR33)  2010-06-06T00:00:00.000    18   5.84   0.029
# 8   381989 (2010 HR80)  2010-04-28T00:00:00.000  19.9  26.71   0.104
# 9    369454 (2010 NZ1)  2010-07-09T00:00:00.000  19.4  32.78   0.275
#
#   orbit_class period_yr pha q_au_1 q_au_2
# 0      Apollo      4.06   Y   0.84   4.26
# 1      Apollo         1   Y   0.93   1.08
# 2      Apollo      1.31   N   0.39      2
# ...

# %%
#here I renamed data into "df"
pha = df.loc[ (df['pha'] == 'Y') ]
#here you take the column "pha" and check for strings "Y" if TRUE then use the index value and select those observations
#and put this into pha

# %%
#let's check content of pha
pha
#this is all fine
# Out:
#             designation           discovery_date h_mag  i_deg moid_au  \
# 0    419880 (2011 AH37)  2011-01-07T00:00:00.000  19.7   9.65   0.035
# 1    419624 (2010 SO16)  2010-09-17T00:00:00.000  20.5  14.52   0.028
# 5    398188 (2010 LE15)  2010-06-03T00:00:00.000  19.5  13.25   0.024
# 6    395207 (2010 HQ80)  2010-04-25T00:00:00.000  19.6  27.85   0.007
# 7    386847 (2010 LR33)  2010-06-06T00:00:00.000    18   5.84   0.029
# 11    365424 (2010 KX7)  2010-05-16T00:00:00.000  21.9  21.49   0.034
# 19         (2015 FE120)  2015-03-23T00:00:00.000  21.1   22.8   0.013
# 23         (2015 AK280)  2015-01-15T00:00:00.000  21.8  11.37   0.049
# 24         (2015 AY245)  2015-01-14T00:00:00.000  21.2  13.59   0.019
# 38         (2014 SR339)  2014-09-30T00:00:00.000  18.6  29.79   0.036
# 45           (2014 OY1)  2014-07-21T00:00:00.000  19.1  23.01   0.042
# 58         (2014 HQ124)  2014-04-23T00:00:00.000  18.9  26.37   0.007
# ...

# %%
#here you overwrite your original variable "pha",
#with only the column "moid_au"
pha = pha[['moid_au']]

# %%
pha
#these values are ok
# Out:
#     moid_au
# 0     0.035
# 1     0.028
# 5     0.024
# 6     0.007
# 7     0.029
# 11    0.034
# 19    0.013
# 23    0.049
# 24    0.019
# 38    0.036
# 45    0.042
# 58    0.007
# 59    0.026
# 63    0.042
# 69    0.004
# 75    0.015
# 85    0.021
# 91    0.044
# 98    0.017
# 108  0.0002
# 121   0.043
# 142   0.035
# 158   0.013
# 166   0.034
# 168   0.027
# 178    0.05
# 180   0.009
# 181   0.006
# 182   0.028
# 197   0.023

# %%
print(pha.head())
#ok you show the top 5
# Out:
#   moid_au
# 0   0.035
# 1   0.028
# 5   0.024
# 6   0.007
# 7   0.029

# %%
type(pha["moid_au"][0])
# Out:
# str

# %%
#print(type(pha))      # you want to know the type of the values,
                        # you should use pha then select column then 1 variable in index 0
                        # type(pha["moid_au"][0])    <== str !!! 
                        # you can not print strings, so you need to transform this series to float first with
pha["moid_au_2"] = [float(i) for i in pha["moid_au"]]  
pha.plot(kind='hist')   # you want to plot a histogram of this data, ok
                        # you need to select the columns of your dataframe like   pha["moid_au"]
                        # then couple that with the plot function 'hist'
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#instead do this:
pha["moid_au_2"].plot(kind='hist')
#I have the impression that JSON loading the data and then into DataFrame made the numerical values all string format !

# %%
pha["moid_au_2"] = [float(i) for i in pha["moid_au"]]
pha

# %%
#json.load

"""
Signature: json.load(fp, *, cls=None, object_hook=None, parse_float=None, parse_int=None, parse_constant=None, object_pairs_hook=None, **kw)
Docstring:
Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
a JSON document) to a Python object.
"""
