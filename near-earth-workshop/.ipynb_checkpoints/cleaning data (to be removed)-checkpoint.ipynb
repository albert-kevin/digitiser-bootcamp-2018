# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_json("2vr3-k9wn.json")

# %%
df
# Out:
#              designation           discovery_date  h_mag   i_deg  moid_au  \
# 0     419880 (2011 AH37)  2011-01-07T00:00:00.000   19.7    9.65    0.035
# 1     419624 (2010 SO16)  2010-09-17T00:00:00.000   20.5   14.52    0.028
# 2    414772 (2010 OC103)  2010-07-28T00:00:00.000   19.0   23.11    0.333
# 3     414746 (2010 EH20)  2010-03-06T00:00:00.000   18.0   23.89    0.268
# 4    407324 (2010 OB101)  2010-07-18T00:00:00.000   20.7    9.12    0.111
# 5     398188 (2010 LE15)  2010-06-03T00:00:00.000   19.5   13.25    0.024
# 6     395207 (2010 HQ80)  2010-04-25T00:00:00.000   19.6   27.85    0.007
# 7     386847 (2010 LR33)  2010-06-06T00:00:00.000   18.0    5.84    0.029
# 8     381989 (2010 HR80)  2010-04-28T00:00:00.000   19.9   26.71    0.104
# 9      369454 (2010 NZ1)  2010-07-09T00:00:00.000   19.4   32.78    0.275
# 10     365449 (2010 NJ1)  2010-07-03T00:00:00.000   20.3   11.23    0.155
# 11     365424 (2010 KX7)  2010-05-16T00:00:00.000   21.9   21.49    0.034
# 12     356394 (2010 QD2)  2010-08-21T00:00:00.000   17.4   10.64    0.061
# 13           (2015 HF11)  2015-04-17T00:00:00.000   19.2   34.89    0.225
# 14           (2015 GK50)  2015-04-05T00:00:00.000   20.5   19.07    0.237
# 15           (2015 GJ46)  2015-04-11T00:00:00.000   19.3   18.22    0.238
# 16          (2015 FT344)  2015-03-23T00:00:00.000   20.5   12.55    0.203
# 17          (2015 FD341)  2015-03-27T00:00:00.000   18.0   20.55    0.124
# 18          (2015 FU332)  2015-03-31T00:00:00.000   17.3   36.11    0.269
# 19          (2015 FE120)  2015-03-23T00:00:00.000   21.1   22.80    0.013
# 20          (2015 FY117)  2015-03-20T00:00:00.000   21.2   24.33    0.150
# 21          (2015 DX198)  2015-02-17T00:00:00.000   22.1   11.05    0.074
# 22          (2015 BY516)  2015-01-30T00:00:00.000   22.3   12.71    0.139
# 23          (2015 AK280)  2015-01-15T00:00:00.000   21.8   11.37    0.049
# 24          (2015 AY245)  2015-01-14T00:00:00.000   21.2   13.59    0.019
# 25           (2015 AC17)  2015-01-03T00:00:00.000   19.9   29.25    0.238
# 26           (2014 YR43)  2014-12-26T00:00:00.000   19.5   26.46    0.303
# 27           (2014 YS14)  2014-12-24T00:00:00.000   21.1   18.29    0.127
# 28           (2014 XX31)  2014-12-11T00:00:00.000   17.5   35.78    0.475
# 29            (2014 XX7)  2014-12-10T00:00:00.000   19.7   36.71    0.183
# ..                   ...                      ...    ...     ...      ...
# 172          (2010 FY80)  2010-03-28T00:00:00.000   19.7   18.81    0.140
# 173          (2010 FX80)  2010-03-27T00:00:00.000   20.6   36.96    0.535
# 174         (2010 EX119)  2010-03-13T00:00:00.000   19.4   15.57    0.159
# 175          (2010 EN44)  2010-03-12T00:00:00.000   24.3   10.18    0.023
# 176          (2010 EX11)  2010-03-03T00:00:00.000   24.1    9.75    0.029
# 177     C/2010 E3 (WISE)  2010-03-05T00:00:00.000    NaN   96.48    1.546
# 178          (2010 DJ77)  2010-02-20T00:00:00.000   21.6   24.98    0.050
# 179          (2010 DH77)  2010-02-19T00:00:00.000   21.8   34.38    0.146
# 180          (2010 DG77)  2010-02-19T00:00:00.000   21.4   14.81    0.009
# 181          (2010 DM56)  2010-02-19T00:00:00.000   19.9   25.61    0.006
# 182          (2010 DJ56)  2010-02-23T00:00:00.000   19.3   34.84    0.028
# 183          (2010 DH56)  2010-02-20T00:00:00.000   20.3   33.67    0.333
# 184   C/2010 DG56 (WISE)  2010-02-18T00:00:00.000    NaN  160.42    0.650
# 185          (2010 DK34)  2010-02-20T00:00:00.000   20.4   27.34    0.333
# 186          (2010 DM21)  2010-02-16T00:00:00.000   20.2   21.15    0.260
# 187     C/2010 D4 (WISE)  2010-02-28T00:00:00.000    NaN  105.66    6.373
# 188     C/2010 D3 (WISE)  2010-02-26T00:00:00.000    NaN   76.39    3.586
# 189     P/2010 D2 (WISE)  2010-02-25T00:00:00.000    NaN   57.18    2.945
# 190     P/2010 D1 (WISE)  2010-02-17T00:00:00.000    NaN    9.65    1.683
# 191         (2010 CN141)  2010-02-14T00:00:00.000   22.4   23.80    0.060
# 192         (2010 CP140)  2010-02-13T00:00:00.000   19.5   14.47    0.097
# 193          (2010 CC55)  2010-02-11T00:00:00.000   22.5    6.78    0.079
# 194          (2010 CA55)  2010-02-05T00:00:00.000   21.3   58.85    0.151
# 195          (2010 CH18)  2010-02-09T00:00:00.000   19.0   27.15    0.333
# 196          (2010 CG18)  2010-02-06T00:00:00.000   20.8   10.15    0.130
# 197           (2010 CO1)  2010-02-01T00:00:00.000   21.5   24.03    0.023
# 198     P/2010 B2 (WISE)  2010-01-22T00:00:00.000    NaN    8.93    0.630
# 199         (2010 AU118)  2010-01-13T00:00:00.000   17.7   43.73    0.147
# 200          (2010 AG79)  2010-01-13T00:00:00.000   19.9   32.96    0.244
# 201          (2010 AB78)  2010-01-12T00:00:00.000   18.3   33.26    0.206
#
#                orbit_class   period_yr  pha  q_au_1    q_au_2
# 0                   Apollo        4.06    Y    0.84      4.26
# 1                   Apollo        1.00    Y    0.93      1.08
# 2                   Apollo        1.31    N    0.39      2.00
# 3                     Amor        4.24    N    1.25      3.99
# 4                   Apollo        2.06    N    0.77      2.46
# 5                     Aten        0.80    Y    0.63      1.10
# 6                   Apollo        1.96    Y    0.80      2.34
# 7                   Apollo        2.20    Y    0.91      2.48
# 8                   Apollo        1.56    N    0.68      2.02
# 9                   Apollo        1.61    N    0.49      2.26
# 10                    Aten        0.95    N    0.44      1.49
# 11                    Aten        0.98    Y    0.82      1.16
# 12                  Apollo        2.85    N    0.43      3.59
# 13                    Amor        2.99    N    1.22      2.93
# 14                    Amor        5.39    N    1.03      5.12
# 15                  Apollo        4.85    N    0.67      5.06
# 16                    Amor        4.07    N    1.09      4.01
# 17                    Aten        0.93    N    0.31      1.60
# 18                  Apollo        4.27    N    0.67      4.59
# 19                  Apollo        3.38    Y    1.01      3.49
# 20                    Amor        2.87    N    1.14      2.90
# 21                    Amor        2.10    N    1.02      2.25
# 22                  Apollo        3.66    N    0.97      3.77
# 23                  Apollo        4.33    Y    0.79      4.53
# 24                  Apollo        1.20    Y    1.00      1.25
# 25                    Amor        3.39    N    1.22      3.29
# 26                  Apollo        3.92    N    0.97      4.00
# 27                  Apollo        3.87    N    0.84      4.09
# 28                  Apollo        4.73    N    0.36      5.28
# 29                    Amor        4.94    N    1.17      4.64
# ..                     ...         ...  ...     ...       ...
# 172                   Amor        4.42    N    1.05      4.35
# 173                   Amor        3.19    N    1.18      3.15
# 174                 Apollo        2.63    N    0.77      3.04
# 175                 Apollo        1.22    N    0.96      1.33
# 176                   Aten        0.93    N    0.85      1.06
# 177        Parabolic Comet         NaN  n/a    2.27       NaN
# 178                   Aten        0.93    Y    0.75      1.16
# 179                 Apollo        5.90    N    0.95      5.58
# 180                 Apollo        3.02    Y    0.96      3.22
# 181                 Apollo        1.49    Y    0.92      1.69
# 182                 Apollo        1.40    Y    0.94      1.56
# 183                 Apollo        3.35    N    0.97      3.51
# 184                  Comet      555.03  n/a    1.59    133.48
# 185                 Apollo        4.54    N    0.65      4.83
# 186                 Apollo        4.85    N    0.98      4.74
# 187                  Comet      520.06  n/a    7.15    122.19
# 188                  Comet  1254179.62  n/a    4.25  23255.11
# 189  Jupiter-family Comet*       17.30  n/a    3.66      9.72
# 190   Jupiter-family Comet        8.45  n/a    2.67      5.63
# 191                 Apollo        1.87    N    0.91      2.12
# 192                 Apollo        2.62    N    0.88      2.92
# 193                 Apollo        1.92    N    0.82      2.27
# 194                 Apollo       12.13    N    0.67      9.89
# 195                   Amor        4.21    N    1.12      4.09
# 196                   Amor        1.73    N    1.11      1.76
# 197                 Apollo        1.02    Y    0.79      1.23
# 198       Encke-type Comet        5.49  n/a    1.62      4.60
# 199                   Amor        2.06    N    1.13      2.12
# 200                   Amor        4.95    N    1.22      4.59
# 201                   Amor        3.38    N    1.02      3.49
#
# [202 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 10 columns):
# designation       202 non-null object
# discovery_date    202 non-null object
# h_mag             181 non-null float64
# i_deg             202 non-null float64
# moid_au           202 non-null float64
# orbit_class       202 non-null object
# period_yr         200 non-null float64
# pha               202 non-null object
# q_au_1            202 non-null float64
# q_au_2            200 non-null float64
# dtypes: float64(6), object(4)
# memory usage: 15.9+ KB

# %%
df.describe(include='all', percentiles=[.05, .25, .5, .75, 0.95])
#50 percentile = median
# Out:
#              designation           discovery_date       h_mag       i_deg  \
# count                202                      202  181.000000  202.000000
# unique               202                      165         NaN         NaN
# top     P/2010 N1 (WISE)  2010-06-23T00:00:00.000         NaN         NaN
# freq                   1                        3         NaN         NaN
# mean                 NaN                      NaN   20.310497   29.382772
# std                  NaN                      NaN    1.521932   27.307793
# min                  NaN                      NaN   15.600000    0.820000
# 5%                   NaN                      NaN   17.700000    6.788000
# 25%                  NaN                      NaN   19.400000   14.082500
# 50%                  NaN                      NaN   20.300000   22.945000
# 75%                  NaN                      NaN   21.300000   34.202500
# 95%                  NaN                      NaN   22.700000   92.768000
# max                  NaN                      NaN   24.300000  162.300000
#
#            moid_au orbit_class     period_yr  pha      q_au_1        q_au_2
# count   202.000000         202  2.000000e+02  202  202.000000    200.000000
# unique         NaN           9           NaN    3         NaN           NaN
# top            NaN      Apollo           NaN    N         NaN           NaN
# freq           NaN         105           NaN  151         NaN           NaN
# mean      0.330541         NaN  1.072373e+04  NaN    1.063515    235.349500
# std       0.723355         NaN  1.033174e+05  NaN    0.743516   2040.071002
# min       0.000200         NaN  7.200000e-01  NaN    0.140000      1.040000
# 5%        0.014000         NaN  9.395000e-01  NaN    0.430000      1.228000
# 25%       0.054500         NaN  1.855000e+00  NaN    0.772500      2.092500
# 50%       0.149000         NaN  3.250000e+00  NaN    0.970000      3.470000
# 75%       0.268750         NaN  4.390000e+00  NaN    1.110000      4.560000
# 95%       1.529900         NaN  2.737300e+01  NaN    2.225500     16.947000
# max       6.373000         NaN  1.254180e+06  NaN    7.150000  23255.110000

# %% [markdown]
# notice something wrong:
# * "h_mag" we have only 181/202 continuous values, missing 11
# * "period_yr" has 200/202 values, missing 2
# * "q_au_2" has 200/202, probably 2 values wrong
#
# the other columns with categorical data:
# * designation: how many unique values ? sometimes it holds date data, to be cleaned, 202/202 ok
# * discovery_date: object, probably string type, needs to be datetime, split into years and month and day columns, 202/202 ok
# * orbit_class: str 202/202 looks good, perhaps transform into dummy columns for numerical analysis if needed
# * pha: binary values, str type 'Y' or 'N', maybe replace with binary value N=0 and Y=1

# %%
#create a variable
h_mag = df["h_mag"]

# %%
#check all unique values in this column, notice 'nan', could be null or string, must be cleaned
#we could choose to lower the data type from float64 to int and lower the storage space
h_mag.unique()

# %%
h_mag[ h_mag.isnull() ]
#these are all the records with null values, (21x values, 10% that's a lot !)
#what we could try is fill in with dummy values based on mean values

# %%
plt.figure(figsize=(12,8))
h_mag.plot.hist(bins=len(h_mag))
plt.plot()

#this shows some sort of a normal distribution, with a mean=20.3 and a standard deviation=1.52
#the range = 24.3 - 15.6 = 8,7
#let's check the

# %%
np.mean(h_mag[h_mag.notnull()])

# %%
np.median(h_mag[h_mag.notnull()])

# %%
#this is GOOD ! this means that we can use 20.3 as a default value to replace the NULL values

# %%
h_mag[ h_mag.isnull() ] = float(20.3)

# %%
#let's work on "period_yr"
period_yr = df["period_yr"]

# %%
period_yr.unique()
# again some nan values
# some extremely large numbers, lets check

# %%
period_yr[ period_yr.isnull() ]
#ok so only 2x nan values

# %%
#between Q1 and Q3 : 1.85 and 4.39
#so, what are the values inside this ideal IQR range ? 
period_yr[ (period_yr > 1.855000e+00) & (period_yr < 4.390000e+00) ]
#Maybe we need a z-score for this...

# %%
x = period_yr[ (period_yr > 9.405000e-01) & (period_yr < 2.354150e+01) ]
plt.figure(figsize=(12,8))
x.plot.hist(bins=len(x))
plt.plot()

# %%
np.mean(x)

# %%
np.median(x)

# %%
#quite a uniform distribution, we can replace the 2 nan values with the median value 3.25
period_yr[ period_yr.isnull() ] = float(3.25)

# %%
period_yr[147]

# %%
x = period_yr[ (period_yr > 0) & (period_yr < 10) ]
plt.figure(figsize=(12,8))
x.plot.hist(bins=len(x))
plt.plot()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.distplot(x, bins=40)
#I think if we replace the outlier values with these median values that the distribution becomes more normal,
#but I am afraid this would damage the truth these numbers are telling, maybe a sigma 2 or 3 cutoff would be better...
#don't know how to do or if important

# %%
#ok so now we should try to clean "q_au_1"
q_au_1 = df["q_au_1"]
q_au_2 = df["q_au_2"]

# %%
q_au_1.unique()
# looking rather normal

# %%
q_au_2.unique()

# this should be cleaned...

# %%
#show only the values between the 5% and 95% range, erase the outliers
x = q_au_2[ (q_au_2 > 1.228000) & (q_au_2 < 16.947000) ]
plt.figure(figsize=(12,8))
x.plot.hist(bins=len(x))
plt.plot()

# %%
q_au_2[ q_au_2.isnull() ]
#ok so only 2x nan values

# %%
np.median(x)

# %%
#quite a uniform distribution, we can replace the 2 nan values with the median value 3.25
q_au_2[ q_au_2.isnull() ] = float(3.47)

# %%
#leaving the outliers...

# %%
designation = df["designation"]

# %%
designation.nunique()
# we have 202 unique observations/labels

# %%
designation[designation.unique()]
# we should clean up this data, remove the weird number, remove the date number, and simply keep the code like "AH37"
# as a string value, we can try to use regular expressions for this

# %%
text = designation.unique()[0]
print (text)
#let's exercise cleaning this one thing...

# %%
import re
#loading regex / regular expression tools
#also go to https://regex101.com/  for getting the right code
#check out : https://en.wikipedia.org/wiki/Provisional_designation_in_astronomy   to figure out the letter combinations

# %%
"""
example text:

419880 (2011 AH37)
(2015 HF11)
C/2010 E3 (WISE)
(2010 CP140)

[ABCDEFGHJKLMNOPQRSTUVWXY][ABCDEFGHJKLMNOPQRSTUVWXYZ]?[\d]+
"""

# %%
regex = r"[ABCDEFGHJKLMNOPQRSTUVWXY][ABCDEFGHJKLMNOPQRSTUVWXYZ]?[\d]+"

# %%
test_str = ("419880 (2011 AH37)\n"
            "(2015 HF11)\n"
            "C/2010 E3 (WISE)\n"
            "(2010 CP140)")

# %%
re.findall(regex, test_str)

# %%
#ok, so this is proove we can extract this content and now we need to create a function to automate this in the dataset
#if we replace the test_str with the "designation" data

# %%
test_str = designation.values
test_str

# %%
for test_str in designation:
    print (test_str)
    print (re.findall(regex, test_str))
    #if we verify this list we can see mistakes that we need to resolve
    #if empty fill in original value or do another regex translation...

# %%
from datetime import datetime

# %%
discovery_date = df["discovery_date"]

# %%
discovery_date[0]

# %%
discovery_date[0].split("T")

# %%
one_date = discovery_date[0].split("T")[0]
one_date

# %%
one_date = datetime.strptime(one_date, "%Y-%m-%d")
one_date

# %%
print (one_date.year)
print (one_date.month)
print (one_date.day)

# %%
#now we update the dataframe with the right columns

# %%
df["discovery_date"] = discovery_date.apply(lambda x: x.split("T")[0])
df["discovery_date"]

# %%
df["discovery_year"] = df["discovery_date"].apply(lambda x: int(x.split("-")[0]))

# %%
df["discovery_month"] = df["discovery_date"].apply(lambda x: int(x.split("-")[1]))

# %%
df["discovery_day"] = df["discovery_date"].apply(lambda x: int(x.split("-")[2]))

# %%
df.drop(['discovery_date'], axis=1, inplace=True)
#removing the original date string

# %%
#... work in progress, quite fun... could all be worthless  ! :-)

# %%
"""
http://4cminews.com/?p=30879
https://en.wikipedia.org/wiki/2016_WF9

designation    = year + identifier of the object in space (ex: 2016 WF9) - wikipedia.org/wiki/2016_WF9
discovery_date = the date the NEOWISE space RADAR detected the object (discovery: first observed) yyyy-mm-dd
h_mag          = absolute magnitude of the object in log scale (ex: H (mag)= 20.1) - wikipedia.org/wiki/Absolute_magnitude
               = only objects larger than roughly 140 meters in diameter (or absolute magnitude, H > 22)
               = see : https://en.wikipedia.org/wiki/Minimum_orbit_intersection_distance
i_deg          = inclination degree of the orbit (irrelevant), the tilt of the object orbit around a body
moid_au        = minimum orbit intersection distance
               = An object is classified as a potentially hazardous object (PHO) – that is,posing a possible risk to Earth –
               = if, among other conditions, its Earth MOID is less than 0.05 AU.
               = (MOID < 0.05)
               = https://en.wikipedia.org/wiki/Minimum_orbit_intersection_distance
               = ex: earth MOID for 2016_WF9 = 0.0156 AU ~ MOID (au): 0.015 in dataset
orbit_class    = group name of the Near Earth Orbit route around the sun compared to earth (irrelevant)
period_yr      = how many earth years the object makes it's own full orbit
               = the time a given astronomical object takes to complete one orbit around another object
               = in degrees °, ex:  Inclination	14.995°  or i (deg): 15 (irrelevant)
pha            = potentially hazardous asteroids (Y/N) binary data
               = suspected extinct comet, classified as near-Earth object and potentially hazardous asteroid of Apollo group
q_au_1         = (AU) min amplitude (= earth is at 1 AU)
               = q (au): 0.98 or Perihelion  0.9816 AU
               = the point where the body comes closest to the Sun
q_au_2         = (AU) max amplitude (= earth is at 1 AU)
               = Q (au): 4.76 or Aphelion  4.7614 AU
               = which is the point in the orbit where the celestial body is farthest from the Sun
               = https://en.wikipedia.org/wiki/Perihelion_and_aphelion
"""
