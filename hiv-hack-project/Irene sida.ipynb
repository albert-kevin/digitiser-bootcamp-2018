# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = 'ARTcases_final.xlsx'

cases = pd.read_excel(file)

cases.head(10)
# Out:
#          geoUnit  Year Gender  Age geoLevel  ARTcases  ARTcases.sd  cnt  Type
# 0         Arusha  2006   Both  All   Region      3677          NaN    1  Meta
# 1         Arusha  2007   Both  All   Region      5896          NaN    1  Meta
# 2         Arusha  2008   Both  All   Region      8678          0.0    2  Meta
# 3         Arusha  2009   Both  All   Region     12038          NaN    1  Meta
# 4         Arusha  2010   Both  All   Region     16268          NaN    1  Meta
# 5         Arusha  2011   Both  All   Region     24310          NaN    1  Meta
# 6         Arusha  2012   Both  All   Region     25375          NaN    1  Meta
# 7  Dar es Salaam  2006   Both  All   Region     18214          NaN    1  Meta
# 8  Dar es Salaam  2007   Both  All   Region     34770          NaN    1  Meta
# 9  Dar es Salaam  2008   Both  All   Region     47423          0.0    2  Meta

# %%
other= pd.read_csv('HIVDR_hackathonDF_c20180727_JC.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe7 in position 4: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-ea376ef0be83> in <module>()
# ----> 1 other= pd.read_csv('HIVDR_hackathonDF_c20180727_JC.csv')
#       2 print(other)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe7 in position 4: invalid continuation byte

# %%
cases2 = pd.read_excel('ARTcoverage_final.xlsx')

print(cases2)
# Out:
#      Year        geoUnit Gender    Age geoLevel  ARTcoverage
# 0    2006         Arusha   Both  15-49   Region     0.218931
# 1    2006  Dar es Salaam   Both  15-49   Region     0.220762
# 2    2006         Dodoma   Both  15-49   Region     0.076819
# 3    2006         Iringa   Both  15-49   Region     0.074904
# 4    2006         Kagera   Both  15-49   Region     0.043719
# 5    2006         Kigoma   Both  15-49   Region     0.030468
# 6    2006    Kilimanjaro   Both  15-49   Region     0.169646
# 7    2006          Lindi   Both  15-49   Region     0.102916
# 8    2006        Manyara   Both  15-49   Region     0.091859
# 9    2006           Mara   Both  15-49   Region     0.046983
# 10   2006          Mbeya   Both  15-49   Region     0.049251
# 11   2006       Morogoro   Both  15-49   Region     0.056880
# 12   2006         Mtwara   Both  15-49   Region     0.089581
# 13   2006         Mwanza   Both  15-49   Region     0.048592
# 14   2006          Pwani   Both  15-49   Region     0.064210
# 15   2006          Rukwa   Both  15-49   Region     0.016133
# 16   2006         Ruvuma   Both  15-49   Region     0.059925
# 17   2006      Shinyanga   Both  15-49   Region     0.018179
# 18   2006        Singida   Both  15-49   Region     0.060264
# 19   2006         Tabora   Both  15-49   Region     0.027885
# 20   2006          Tanga   Both  15-49   Region     0.094734
# 21   2007         Arusha   Both  15-49   Region     0.351091
# 22   2007  Dar es Salaam   Both  15-49   Region     0.421522
# 23   2007         Dodoma   Both  15-49   Region     0.183112
# 24   2007         Iringa   Both  15-49   Region     0.167832
# 25   2007         Kagera   Both  15-49   Region     0.123504
# 26   2007         Kigoma   Both  15-49   Region     0.068752
# 27   2007    Kilimanjaro   Both  15-49   Region     0.326303
# 28   2007          Lindi   Both  15-49   Region     0.225994
# 29   2007        Manyara   Both  15-49   Region     0.110294
# ..    ...            ...    ...    ...      ...          ...
# 117  2011         Mtwara   Both  15-49   Region     0.572460
# 118  2011         Mwanza   Both  15-49   Region     0.637917
# 119  2011          Pwani   Both  15-49   Region     0.573105
# 120  2011          Rukwa   Both  15-49   Region     0.351586
# 121  2011         Ruvuma   Both  15-49   Region     0.580058
# 122  2011      Shinyanga   Both  15-49   Region     0.365009
# 123  2011        Singida   Both  15-49   Region     0.455610
# 124  2011         Tabora   Both  15-49   Region     0.506621
# 125  2011          Tanga   Both  15-49   Region     0.743449
# 126  2012         Arusha   Both  15-49   Region     1.380671
# 127  2012  Dar es Salaam   Both  15-49   Region     1.306991
# 128  2012         Dodoma   Both  15-49   Region     0.528583
# 129  2012         Iringa   Both  15-49   Region     0.994931
# 130  2012         Kagera   Both  15-49   Region     0.507073
# 131  2012         Kigoma   Both  15-49   Region     0.327170
# 132  2012    Kilimanjaro   Both  15-49   Region     0.962765
# 133  2012          Lindi   Both  15-49   Region     1.098335
# 134  2012        Manyara   Both  15-49   Region     1.139900
# 135  2012           Mara   Both  15-49   Region     0.659483
# 136  2012          Mbeya   Both  15-49   Region     0.758425
# 137  2012       Morogoro   Both  15-49   Region     0.750274
# 138  2012         Mtwara   Both  15-49   Region     0.698600
# 139  2012         Mwanza   Both  15-49   Region     0.717003
# 140  2012          Pwani   Both  15-49   Region     0.774327
# 141  2012          Rukwa   Both  15-49   Region     0.703667
# 142  2012         Ruvuma   Both  15-49   Region     0.620938
# 143  2012      Shinyanga   Both  15-49   Region     0.415146
# 144  2012        Singida   Both  15-49   Region     0.570815
# 145  2012         Tabora   Both  15-49   Region     0.384368
# 146  2012          Tanga   Both  15-49   Region     0.926138
#
# [147 rows x 6 columns]

# %%
#file names = ARTneed_final.xlsx EducationFin_final.xlsx  HCTS_final.xlsx 
#HealthFinPub_final.xlsx 
#HIVcases_final.xlsx 
#HIVprevalence_final.xlsx 
#Indicators_final.xlsx 
#Population_final.xlsx 
#rptHIVcases_final.xlsx 
#VCTcases_final.xlsx 
#VLS_final.xlsx

# %%
education= pd.read_excel('EducationFin_final.xlsx')

print (education)
# Out:
#           geoUnit  Year Gender  Age geoLevel  EducationFin  EducationFin.sd  \
# 0          Arusha  2009   Both  All   Region     193656000              NaN
# 1          Arusha  2010   Both  All   Region   48361892000              NaN
# 2          Arusha  2011   Both  All   Region   52697126000              NaN
# 3           Coast  2010   Both  All   Region   31080888000              NaN
# 4           Coast  2011   Both  All   Region   36008203000              NaN
# 5   Dar es Salaam  2009   Both  All   Region     277845000              NaN
# 6   Dar es Salaam  2010   Both  All   Region   66254847000              NaN
# 7   Dar es Salaam  2011   Both  All   Region   78275783000              NaN
# 8          Dodoma  2009   Both  All   Region     239702000              NaN
# 9          Dodoma  2010   Both  All   Region   48698715000              NaN
# 10         Dodoma  2011   Both  All   Region   61450190000              NaN
# 11         Iringa  2010   Both  All   Region   51690835000              NaN
# 12         Iringa  2011   Both  All   Region   65820861000              NaN
# 13         Kagera  2010   Both  All   Region   56737932000              NaN
# 14         Kagera  2011   Both  All   Region   62719552000              NaN
# 15         Kigoma  2010   Both  All   Region   36810900000              NaN
# 16         Kigoma  2011   Both  All   Region   44575125700              NaN
# 17    Kilimanjaro  2010   Both  All   Region   65038763000              NaN
# 18    Kilimanjaro  2011   Both  All   Region   76399589000              NaN
# 19          Lindi  2010   Both  All   Region   22321345000              NaN
# 20          Lindi  2011   Both  All   Region   24897490000              NaN
# 21        Manyara  2009   Both  All   Region     155038000              NaN
# 22        Manyara  2010   Both  All   Region   33117602000              NaN
# 23        Manyara  2011   Both  All   Region   36382930000              NaN
# 24           Mara  2009   Both  All   Region     227925000              NaN
# 25           Mara  2010   Both  All   Region   48066371000              NaN
# 26           Mara  2011   Both  All   Region   54704190000              NaN
# 27          Mbeya  2010   Both  All   Region   67752441000              NaN
# 28          Mbeya  2011   Both  All   Region   88895816000              NaN
# 29       Morogoro  2010   Both  All   Region   50887755000              NaN
# 30       Morogoro  2011   Both  All   Region   65070452000              NaN
# 31         Mtwara  2010   Both  All   Region   32946707000              NaN
# 32         Mtwara  2011   Both  All   Region   43298012990              NaN
# 33         Mwanza  2010   Both  All   Region   85793896000              NaN
# 34         Mwanza  2011   Both  All   Region   96005480000              NaN
# 35          Rukwa  2010   Both  All   Region   27401885000              NaN
# 36          Rukwa  2011   Both  All   Region   33950549000              NaN
# 37         Ruvuma  2010   Both  All   Region   39957898000              NaN
# 38         Ruvuma  2011   Both  All   Region   43598386000              NaN
# 39      Shinyanga  2010   Both  All   Region   63517206000              NaN
# 40      Shinyanga  2011   Both  All   Region   68329779000              NaN
# 41        Singida  2009   Both  All   Region     169354000              NaN
# 42        Singida  2010   Both  All   Region   31207653000              NaN
# 43        Singida  2011   Both  All   Region   34147376000              NaN
# 44         Tabora  2010   Both  All   Region   36504315000              NaN
# 45         Tabora  2011   Both  All   Region   45622485000              NaN
# 46          Tanga  2009   Both  All   Region     258576000              NaN
# 47          Tanga  2010   Both  All   Region   54186051000              NaN
# 48          Tanga  2011   Both  All   Region   73047951000              NaN
#
#     cnt  Type
# 0     1  Meta
# 1     1  Meta
# 2     1  Meta
# 3     1  Meta
# 4     1  Meta
# 5     1  Meta
# 6     1  Meta
# 7     1  Meta
# 8     1  Meta
# 9     1  Meta
# 10    1  Meta
# 11    1  Meta
# 12    1  Meta
# 13    1  Meta
# 14    1  Meta
# 15    1  Meta
# 16    1  Meta
# 17    1  Meta
# 18    1  Meta
# 19    1  Meta
# 20    1  Meta
# 21    1  Meta
# 22    1  Meta
# 23    1  Meta
# 24    1  Meta
# 25    1  Meta
# 26    1  Meta
# 27    1  Meta
# 28    1  Meta
# 29    1  Meta
# 30    1  Meta
# 31    1  Meta
# 32    1  Meta
# 33    1  Meta
# 34    1  Meta
# 35    1  Meta
# 36    1  Meta
# 37    1  Meta
# 38    1  Meta
# 39    1  Meta
# 40    1  Meta
# 41    1  Meta
# 42    1  Meta
# 43    1  Meta
# 44    1  Meta
# 45    1  Meta
# 46    1  Meta
# 47    1  Meta
# 48    1  Meta

# %%
import seaborn as sns

hivprev = pd.read_excel('HIVprevalence_final.xlsx')

tan_prev= hivprev[hivprev['geoUnit']=='Tanzania']
tan_prev= tan_prev.drop('geoUnit', 1)


print(hivprev)


sns.lmplot(data=tan_prev,
         x="Year",
         y="HIVprevalence")

# Display the plot
plt.show()
# Out:
#      Year           geoUnit  HIVprevalence Gender    Age         Type geoLevel
# 0    1995            Arusha           3.86   Both  15-49  Calculation   Region
# 1    1995     Dar es Salaam          11.64   Both  15-49  Calculation   Region
# 2    1995            Dodoma           5.12   Both  15-49  Calculation   Region
# 3    1995            Iringa          14.14   Both  15-49  Calculation   Region
# 4    1995            Kagera           7.27   Both  15-49  Calculation   Region
# 5    1995   Kaskazini Pemba           0.25   Both  15-49  Calculation   Region
# 6    1995  Kaskazini Unguja           0.55   Both  15-49  Calculation   Region
# 7    1995            Kigoma           4.05   Both  15-49  Calculation   Region
# 8    1995       Kilimanjaro           4.60   Both  15-49  Calculation   Region
# 9    1995      Kusini Pemba           0.62   Both  15-49  Calculation   Region
# 10   1995     Kusini Unguja           0.32   Both  15-49  Calculation   Region
# 11   1995             Lindi           3.19   Both  15-49  Calculation   Region
# 12   1995              Mara           7.30   Both  15-49  Calculation   Region
# 13   1995             Mbeya          14.13   Both  15-49  Calculation   Region
# 14   1995   Mjini Magharibi           1.44   Both  15-49  Calculation   Region
# 15   1995          Morogoro           5.98   Both  15-49  Calculation   Region
# 16   1995            Mtwara           5.06   Both  15-49  Calculation   Region
# 17   1995            Mwanza           8.23   Both  15-49  Calculation   Region
# 18   1995             Pwani           8.10   Both  15-49  Calculation   Region
# 19   1995             Rukwa           8.43   Both  15-49  Calculation   Region
# 20   1995            Ruvuma           8.62   Both  15-49  Calculation   Region
# 21   1995         Shinyanga          11.23   Both  15-49  Calculation   Region
# 22   1995           Singida           4.23   Both  15-49  Calculation   Region
# 23   1995            Tabora           9.33   Both  15-49  Calculation   Region
# 24   1995             Tanga           5.52   Both  15-49  Calculation   Region
# 25   1996            Arusha           3.96   Both  15-49  Calculation   Region
# 26   1996     Dar es Salaam          11.86   Both  15-49  Calculation   Region
# 27   1996            Dodoma           5.27   Both  15-49  Calculation   Region
# 28   1996            Iringa          14.66   Both  15-49  Calculation   Region
# 29   1996            Kagera           7.39   Both  15-49  Calculation   Region
# ..    ...               ...            ...    ...    ...          ...      ...
# 607  2017             Rukwa           4.42   Both  15-49  Calculation   Region
# 608  2017            Ruvuma           5.55   Both  15-49  Calculation   Region
# 609  2017         Shinyanga           5.54   Both  15-49  Calculation   Region
# 610  2017            Simiyu           3.46   Both  15-49  Calculation   Region
# 611  2017           Singida           2.85   Both  15-49  Calculation   Region
# 612  2017            Tabora           4.86   Both  15-49  Calculation   Region
# 613  2017             Tanga           4.08   Both  15-49  Calculation   Region
# 614  1995          Tanzania           7.82   Both  15-49  Calculation  Country
# 615  1996          Tanzania           8.30   Both  15-49  Calculation  Country
# 616  1997          Tanzania           7.99   Both  15-49  Calculation  Country
# 617  1998          Tanzania           8.46   Both  15-49  Calculation  Country
# 618  1999          Tanzania           8.22   Both  15-49  Calculation  Country
# 619  2000          Tanzania           7.96   Both  15-49  Calculation  Country
# 620  2001          Tanzania           7.73   Both  15-49  Calculation  Country
# 621  2002          Tanzania           6.92   Both  15-49  Calculation  Country
# 622  2003          Tanzania           6.50   Both  15-49  Calculation  Country
# 623  2004          Tanzania           6.31   Both  15-49  Calculation  Country
# 624  2005          Tanzania           6.15   Both  15-49  Calculation  Country
# 625  2006          Tanzania           6.01   Both  15-49  Calculation  Country
# 626  2007          Tanzania           5.84   Both  15-49  Calculation  Country
# 627  2008          Tanzania           5.69   Both  15-49  Calculation  Country
# 628  2009          Tanzania           5.47   Both  15-49  Calculation  Country
# 629  2010          Tanzania           5.27   Both  15-49  Calculation  Country
# 630  2011          Tanzania           5.09   Both  15-49  Calculation  Country
# 631  2012          Tanzania           4.44   Both  15-49  Calculation  Country
# 632  2013          Tanzania           4.28   Both  15-49  Calculation  Country
# 633  2014          Tanzania           4.51   Both  15-49  Calculation  Country
# 634  2015          Tanzania           4.33   Both  15-49  Calculation  Country
# 635  2016          Tanzania           4.13   Both  15-49  Calculation  Country
# 636  2017          Tanzania           3.96   Both  15-49  Calculation  Country
#
# [637 rows x 7 columns]

# %%
indi = pd.read_excel('Indicators_final.xlsx')

#tan_prev= hivprev[hivprev['geoUnit']=='Tanzania']
#tan_prev= tan_prev.drop('geoUnit', 1)

pop = pd.read_excel('rptHIVcases_final.xlsx')

# QUESTION: how to ask "show me if there is some Tanzania in the file".

popt = pop[pop['geoUnit']== ''] 
#Population_final.xlsx 
#rptHIVcases_final.xlsx 
#VCTcases_final.xlsx 
#VLS_final.xlsx
print(pop)


#sns.lmplot(data=tan_prev,
 #        x="Year",
  #       y="HIVprevalence")

# Display the plot
#plt.show()
# Out:
#      Year        geoUnit Gender  Age geoLevel  rptHIVcases  Type
# 0    1983         Arusha   Both  All   Region         0.00  Meta
# 1    1984         Arusha   Both  All   Region         0.00  Meta
# 2    1985         Arusha   Both  All   Region         0.00  Meta
# 3    1986         Arusha   Both  All   Region        10.00  Meta
# 4    1987         Arusha   Both  All   Region        47.00  Meta
# 5    1988         Arusha   Both  All   Region       217.00  Meta
# 6    1989         Arusha   Both  All   Region       433.00  Meta
# 7    1990         Arusha   Both  All   Region       647.00  Meta
# 8    1991         Arusha   Both  All   Region      1117.00  Meta
# 9    1992         Arusha   Both  All   Region      1637.00  Meta
# 10   1993         Arusha   Both  All   Region      2185.00  Meta
# 11   1994         Arusha   Both  All   Region      2368.00  Meta
# 12   1995         Arusha   Both  All   Region      2615.00  Meta
# 13   1996         Arusha   Both  All   Region      2787.00  Meta
# 14   1997         Arusha   Both  All   Region      3244.00  Meta
# 15   1998         Arusha   Both  All   Region      3567.00  Meta
# 16   1999         Arusha   Both  All   Region      3948.00  Meta
# 17   2000         Arusha   Both  All   Region      4196.00  Meta
# 18   2001         Arusha   Both  All   Region      4688.00  Meta
# 19   2002         Arusha   Both  All   Region      4785.00  Meta
# 20   2003         Arusha   Both  All   Region      6476.00  Meta
# 21   2004         Arusha   Both  All   Region      6569.00  Meta
# 22   1983  Dar es Salaam   Both  All   Region         0.00  Meta
# 23   1984  Dar es Salaam   Both  All   Region         0.00  Meta
# 24   1985  Dar es Salaam   Both  All   Region        51.00  Meta
# 25   1986  Dar es Salaam   Both  All   Region       471.00  Meta
# 26   1987  Dar es Salaam   Both  All   Region      1470.00  Meta
# 27   1988  Dar es Salaam   Both  All   Region      3093.00  Meta
# 28   1989  Dar es Salaam   Both  All   Region      5209.00  Meta
# 29   1990  Dar es Salaam   Both  All   Region      7246.00  Meta
# ..    ...            ...    ...  ...      ...          ...   ...
# 515  2004          Pwani   Both  All   Region     67473.10  Calc
# 516  2008          Pwani   Both  All   Region     68002.79  Calc
# 517  2012          Pwani   Both  All   Region     63217.14  Calc
# 518  2017          Pwani   Both  All   Region     67890.02  Calc
# 519  2004          Rukwa   Both  All   Region     72798.54  Calc
# 520  2008          Rukwa   Both  All   Region     68544.43  Calc
# 521  2012          Rukwa   Both  All   Region     70863.59  Calc
# 522  2017          Rukwa   Both  All   Region     84905.79  Calc
# 523  2004         Ruvuma   Both  All   Region     79605.97  Calc
# 524  2008         Ruvuma   Both  All   Region     76896.41  Calc
# 525  2012         Ruvuma   Both  All   Region     97403.52  Calc
# 526  2017         Ruvuma   Both  All   Region     92338.40  Calc
# 527  2004      Shinyanga   Both  All   Region    196640.67  Calc
# 528  2008      Shinyanga   Both  All   Region    262651.16  Calc
# 529  2012      Shinyanga   Both  All   Region    152444.78  Calc
# 530  2017      Shinyanga   Both  All   Region    298626.61  Calc
# 531  2012         Simiyu   Both  All   Region     47443.64  Calc
# 532  2017         Simiyu   Both  All   Region     67721.42  Calc
# 533  2004        Singida   Both  All   Region     36877.50  Calc
# 534  2008        Singida   Both  All   Region     34953.77  Calc
# 535  2012        Singida   Both  All   Region     45693.32  Calc
# 536  2017        Singida   Both  All   Region     58340.12  Calc
# 537  2004         Tabora   Both  All   Region    133135.27  Calc
# 538  2008         Tabora   Both  All   Region    138939.26  Calc
# 539  2012         Tabora   Both  All   Region    119403.31  Calc
# 540  2017         Tabora   Both  All   Region    156662.77  Calc
# 541  2004          Tanga   Both  All   Region     97568.15  Calc
# 542  2008          Tanga   Both  All   Region     90258.67  Calc
# 543  2012          Tanga   Both  All   Region     49127.34  Calc
# 544  2017          Tanga   Both  All   Region    113650.25  Calc
#
# [545 rows x 7 columns]
